# %%
import cv2
import numpy as np
import os
import cv2
from ultralytics import YOLO
from tqdm import tqdm

# %%
def save_video_frames(video_path, video_number):
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    # Create directory for the video frames
    output_dir = f"train\\Task2\\frames"
    os.makedirs(output_dir, exist_ok=True)
    
    frame_number = 0
    while True:
        # Read a frame
        ret, frame = cap.read()
        
        # Break the loop if no frame is read (end of video)
        if not ret:
            break
        
        # Save the frame as an image file
        frame_filename = os.path.join(output_dir, f"video_{video_number}_frame_{frame_number:04d}.png")
        cv2.imwrite(frame_filename, frame)
        
        # Increment the frame number
        frame_number += 1
    
    # Release the video capture object
    cap.release()
    print(f"Saved {frame_number} frames to {output_dir}")
    
def get_video_files_from_folder(folder_path, extensions=None):
    if extensions is None:
        # Define default video file extensions
        extensions = ['.mp4', '.avi', '.mov', '.mkv', '.flv', '.wmv']

    # List all files in the directory
    all_files = os.listdir(folder_path)
    
    # Filter files based on extensions
    video_files = [f for f in all_files if os.path.splitext(f)[1].lower() in extensions]
    
    # Full path for video files
    video_files = [os.path.join(folder_path, f) for f in video_files]
    
    return video_files

# %%
def get_txt_files_from_folder(folder_path):
    # List all files in the directory
    all_files = os.listdir(folder_path)
    
    # Filter files to get only .txt files
    txt_files = [f for f in all_files if f.endswith('.txt')]
    
    # Full path for txt files
    txt_files = [os.path.join(folder_path, f) for f in txt_files]
    
    return txt_files

def modify_lines_in_file(input_file, output_folder,i):
    
    with open(input_file, 'r') as infile:
        for line_number, line in enumerate(infile):
            if line_number == 0:
                continue  # Skip the first line
            # Split the line into numbers
            numbers = line.split()
            if numbers:
                # Replace the first number with 0
                numbers[0] = '0'
                # Join the numbers back into a string
                modified_line = ' '.join(numbers)
                output_file = output_folder+ f"\\video_{i}_frame_{line_number:04d}.txt"
                # Open the new output file for writing
                with open(output_file, 'w') as outfile:
                    # Write the modified line to the new output file
                    outfile.write(modified_line + '\n')

def process_txt_files(folder_path, output_folder):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)
    
    # Get the list of txt files
    txt_files = get_txt_files_from_folder(folder_path)
    i=1
    # Process each txt file
    for txt_file in txt_files:
        # Define the output file name
        base_name = os.path.basename(txt_file)
        output_file = os.path.join(output_folder, base_name)
        
        # Modify lines and write to the new file
        modify_lines_in_file(txt_file, output_folder,i)
        i+=1
        print(f"Processed {txt_file} and saved to {output_file}")

# %%
def read_input_txt(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        second_line = lines[1].strip().split()
        numbers = [int(l) for l in second_line[1:]]
        
        return lines[0], tuple(numbers)

# %%
def load_images(directory):
    images = []
    for filename in tqdm(os.listdir(directory)):
        if filename.endswith(".png") or filename.endswith(".jpg"):
            img = cv2.imread(os.path.join(directory, filename))
            if img is not None:
                images.append(img)
    return images

def load_queries(directory):
    queries = []
    for filename in tqdm(os.listdir(directory)):
        if filename.endswith(".txt"):
            with open(os.path.join(directory, filename), 'r') as file:
                # Read all lines and strip newline characters
                query = [line.strip().split() for line in file]
                query = [int(q) for q in query[0]]
            queries.append((query[0],query[1:]))
    return queries

def display_image(image):
    cv2.imshow('Image', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
def get_rectangle_area(coords):
    # Unpack coordinates
    x1, y1, x2, y2 = coords
    # Calculate width and height
    width = abs(x2 - x1)
    height = abs(y2 - y1)
    return width * height

def find_median_area(area1, area2):
    return (area1 + area2) / 2

def calculate_third_rectangle(rect1, rect2):
    # Calculate areas of the first two rectangles
    area1 = get_rectangle_area(rect1)
    area2 = get_rectangle_area(rect2)
    
    # Find median area
    median_area = find_median_area(area1, area2)
    
    # Calculate the direction vector and midpoint
    center1 = ((rect1[0] + rect1[2]) / 2, (rect1[1] + rect1[3]) / 2)
    center2 = ((rect2[0] + rect2[2]) / 2, (rect2[1] + rect2[3]) / 2)
    
    # Calculate the direction vector from rect1 to rect2
    direction_vector = np.array([center2[0] - center1[0], center2[1] - center1[1]])
    distance = np.linalg.norm(direction_vector)
    direction_vector /= distance  # Normalize direction vector
    
    # Determine the center point for the third rectangle
    center3 = (center2[0] + direction_vector[0] * distance, center2[1] + direction_vector[1] * distance)
    
    # Calculate the dimensions of the third rectangle
    width1 = abs(rect1[2] - rect1[0])
    height1 = abs(rect1[3] - rect1[1])
    
    # Assuming the third rectangle maintains the same aspect ratio as the first rectangle
    aspect_ratio = width1 / height1
    width3 = np.sqrt(median_area * aspect_ratio)
    height3 = median_area / width3
    
    # Calculate the coordinates of the third rectangle centered at center3
    rect3 = (
        int(center3[0] - width3 / 2), int(center3[1] - height3 / 2),
        int(center3[0] + width3 / 2), int(center3[1] + height3 / 2)
    )
    
    return rect3

# %%
def predict(chosen_model, img, classes=[], conf=0.5, iou=0.7):
    if classes:
        results = chosen_model.predict(img, classes=classes, conf=conf, iou= iou)
    else:
        results = chosen_model.predict(img, conf=conf, iou= iou)

    return results

def predict_and_detect(chosen_model, img, classes=[], conf=0.5, iou=0.7):
    results = predict(chosen_model, img, classes, conf=conf, iou= iou)

    for result in results:
        for box in result.boxes:
            cv2.rectangle(img, (int(box.xyxy[0][0]), int(box.xyxy[0][1])),
                          (int(box.xyxy[0][2]), int(box.xyxy[0][3])), (255, 0, 0), 2)
            cv2.putText(img, f"{result.names[int(box.cls[0])]}",
                        (int(box.xyxy[0][0]), int(box.xyxy[0][1]) - 10),
                        cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 0), 1)
    return img, results

# %%
class PredictionBox:
    def __init__(self, bbox, confidence, cls, iou_with_ancestor):
        self.bbox = bbox
        self.confidence = confidence
        self.cls = cls
        self.iou_with_ancestor = iou_with_ancestor

# %%
def intersection_over_union(rect1, rect2):
    # Unpack coordinates
    x1_min, y1_min, x1_max, y1_max = rect1
    x2_min, y2_min, x2_max, y2_max = rect2

    # Calculate the intersection coordinates
    x_inter_min = max(x1_min, x2_min)
    y_inter_min = max(y1_min, y2_min)
    x_inter_max = min(x1_max, x2_max)
    y_inter_max = min(y1_max, y2_max)

    # Compute the area of the intersection rectangle
    inter_width = max(0, x_inter_max - x_inter_min)
    inter_height = max(0, y_inter_max - y_inter_min)
    inter_area = inter_width * inter_height

    # Compute the area of both rectangles
    area1 = (x1_max - x1_min) * (y1_max - y1_min)
    area2 = (x2_max - x2_min) * (y2_max - y2_min)

    # Compute the union area
    union_area = area1 + area2 - inter_area

    # Compute the Intersection over Union (IoU)
    iou = inter_area / union_area

    return iou

# %%
def ensure_directory_exists(path):
    if not os.path.exists(path):
        os.makedirs(path)

def extract_results(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        extracted_pos = []
        for line in lines[1:]:
            components = line.strip().split()
            last_four = components[-4:]
            extracted_pos.append(tuple([int(num) for num in last_four]))
        
        return extracted_pos

# %%
frames = load_images("train/Task2/dataset/images/train")
labels = load_queries("train/Task2/labels")
# Out:
#   3%|▎         | 50/1667 [00:00<00:26, 60.67it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 frames = load_images("train/Task2/dataset/images/train")
#       2 labels = load_queries("train/Task2/labels")
#
# Cell In[40], line 5, in load_images(directory)
#       3 for filename in tqdm(os.listdir(directory)):
#       4     if filename.endswith(".png") or filename.endswith(".jpg"):
# ----> 5         img = cv2.imread(os.path.join(directory, filename))
#       6         if img is not None:
#       7             images.append(img)
#
# File d:\PythonPath\lib\site-packages\ultralytics\utils\patches.py:26, in imread(filename, flags)
#      15 def imread(filename: str, flags: int = cv2.IMREAD_COLOR):
#      16     """
#      17     Read an image from a file.
#      18
#    (...)
#      24         (np.ndarray): The read image.
#      25     """
# ---> 26     return cv2.imdecode(np.fromfile(filename, np.uint8), flags)
#
# KeyboardInterrupt:

# %%
def pascal_voc_to_yolo(x1, y1, x2, y2, image_w, image_h):
    return [((x2 + x1)/(2*image_w)), ((y2 + y1)/(2*image_h)), (x2 - x1)/image_w, (y2 - y1)/image_h]


yolo_pos_list = []
for label,img in tqdm(zip(labels, frames)):
    pos = label[1]
    h, w, _ = img.shape
    yolo_pos = pascal_voc_to_yolo(pos[0], pos[1], pos[2], pos[3], w, h)
    yolo_pos_list.append(yolo_pos)

dir_path = "train/Task2/labels"
files_in_path = sorted(os.listdir(dir_path), key = lambda x: x[7].isdigit())
for pos, path in zip(yolo_pos_list, files_in_path):
    label = f"0 {pos[0]} {pos[1]} {pos[2]} {pos[3]}"
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        with open(os.path.join(dir_path, path), 'w') as outfile:
                    # Write the modified line to the new output file
                    outfile.write(label)

# %%
rect1 = (10, 10, 30, 40)  # Example coordinates of the first rectangle (x1, y1, x2, y2)
rect2 = (50, 50, 80, 90)
third_rect = calculate_third_rectangle(rect1, rect2)
print("Third rectangle coordinates:", third_rect)

cv2.rectangle(frames[0], (50, 50),
                          (80, 90), (255, 97, 34), 2)
cv2.rectangle(frames[0], (10, 10),
                          (30, 40), (255, 97, 34), 2)

cv2.rectangle(frames[0], (int(third_rect[0]), int(third_rect[1])),
                          (int(third_rect[2]), int(third_rect[3])), (255, 97, 34), 2)
display_image(frames[0])

# %%
def track_videos_from_path(path="train/Task2", model = "yolov8x.pt", verbose=0):
    model = YOLO(model)
    videos = get_video_files_from_folder(path)
    start_positions_txt = get_txt_files_from_folder(path)
    i = 1
    for video_path, st_pos in tqdm(zip(videos[1:2], start_positions_txt[1:2])):
        capture = cv2.VideoCapture(video_path)
        line_0, initial_bbox = read_input_txt(st_pos)
        frames_pred_list = [initial_bbox]

        #Discard the first frame because we already have it 
        ok, frame = capture.read()
        if not ok:
            print('Cannot read the first frame')
            exit()
        
        # Loop through the video frames
        while capture.isOpened():
            # Read a frame from the video
            success, frame = capture.read()
            pb_list = []
            if success:
                # 31,32,34,35,74,75
                results = predict(model, frame, conf=0.005, iou=0.5, classes=[])
                
                for r in results:
                    boxes = r.boxes

                    for box in boxes:
                        x1, y1, x2, y2 = box.xyxy[0]
                        bbox = int(x1), int(y1), int(x2), int(y2)
                        confidence = float(box.conf[0])
                        cls = r.names[int(box.cls[0])]
                        iou_with_ancestor = intersection_over_union(frames_pred_list[-1], bbox)

                        pbox = PredictionBox(bbox, confidence, cls, iou_with_ancestor)
                        pb_list.append(pbox)
                pb_list = [pb for pb in pb_list if pb.iou_with_ancestor >= 0.2]
                pb_list = sorted(pb_list, key= lambda x: (x.iou_with_ancestor), reverse=True)

                if len(pb_list) == 0 and len(frames_pred_list)>1:
                    pos_1 = frames_pred_list[-2]
                    pos_2 = frames_pred_list[-1]
                    actual_pos = calculate_third_rectangle(pos_1, pos_2)
                    frames_pred_list.append(actual_pos)
                elif len(pb_list) == 0 and len(frames_pred_list) > 1:
                    frames_pred_list.append(frames_pred_list[-1])
                else:
                    frames_pred_list.append(pb_list[0].bbox)

                if verbose == 1:
                    for pb in pb_list:
                        cv2.rectangle(frame, (pb.bbox[0], pb.bbox[1]),
                                    (pb.bbox[2], pb.bbox[3]), (255, 0, 0), 2)
                        cv2.putText(frame, f"{pb.cls}",
                                    (pb.bbox[0], pb.bbox[1] - 10),
                                    cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 0), 1)
                    cv2.rectangle(frame, (frames_pred_list[-1][0], frames_pred_list[-1][1]),
                            (frames_pred_list[-1][2], frames_pred_list[-1][3]), (35, 178, 200), 2)
                    cv2.imshow("Image", frame)

                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
            else:
                break
        capture.release()
        cv2.destroyAllWindows()

        if i<10:
            file_path = os.path.join(f"{os.getcwd()}\\train\\Task2\\predited-truth", f"0{i}_pt.txt")
        else:
            file_path = os.path.join(f"{os.getcwd()}\\train\\Task2\\predited-truth", f"{i}_pt.txt")

        ensure_directory_exists(os.path.dirname(file_path))

        with open(file_path, 'w') as file:
            j=1
            file.write(line_0)
            for pos in frames_pred_list:
                file.write(f"{j} {pos[0]} {pos[1]} {pos[2]} {pos[3]}\n")
                j+=1

        i += 1

# %%
track_videos_from_path()
# Out:
# 0it [00:00, ?it/s]
# 0: 384x640 15 persons, 1 traffic light, 2 handbags, 1 suitcase, 1 baseball glove, 1 skateboard, 12 tvs, 2 cell phones, 1883.6ms
# Speed: 3.0ms preprocess, 1883.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 car, 1 traffic light, 4 handbags, 1 suitcase, 1 baseball glove, 1 skateboard, 14 tvs, 2 cell phones, 1874.4ms
# Speed: 3.0ms preprocess, 1874.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 traffic light, 2 handbags, 2 baseball gloves, 3 skateboards, 10 tvs, 2 cell phones, 1 clock, 1851.9ms
# Speed: 2.0ms preprocess, 1851.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 1 traffic light, 1 handbag, 2 baseball gloves, 6 skateboards, 10 tvs, 2 cell phones, 1847.5ms
# Speed: 2.0ms preprocess, 1847.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 traffic light, 1 backpack, 2 handbags, 6 skateboards, 13 tvs, 1 cell phone, 1858.3ms
# Speed: 1.0ms preprocess, 1858.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 car, 1 traffic light, 1 handbag, 1 suitcase, 6 skateboards, 12 tvs, 1 cell phone, 1 clock, 1831.0ms
# Speed: 2.0ms preprocess, 1831.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 traffic light, 1 handbag, 1 suitcase, 1 baseball glove, 4 skateboards, 13 tvs, 1 cell phone, 1829.3ms
# Speed: 3.0ms preprocess, 1829.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 traffic light, 1 handbag, 3 suitcases, 1 baseball bat, 1 baseball glove, 4 skateboards, 13 tvs, 1 cell phone, 1 sink, 1 book, 1817.4ms
# Speed: 2.0ms preprocess, 1817.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 car, 1 traffic light, 1 handbag, 2 suitcases, 2 baseball gloves, 6 skateboards, 18 tvs, 1 cell phone, 1 clock, 1833.7ms
# Speed: 2.0ms preprocess, 1833.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 traffic light, 1 handbag, 2 suitcases, 1 baseball glove, 2 skateboards, 16 tvs, 1 cell phone, 2 sinks, 1 clock, 1850.3ms
# Speed: 1.0ms preprocess, 1850.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 cars, 1 traffic light, 1 handbag, 3 suitcases, 1 baseball glove, 2 skateboards, 17 tvs, 1 cell phone, 1 clock, 1845.6ms
# Speed: 2.0ms preprocess, 1845.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 traffic light, 2 handbags, 1 suitcase, 1 baseball glove, 1 chair, 14 tvs, 2 cell phones, 1 clock, 1866.1ms
# Speed: 2.0ms preprocess, 1866.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 cars, 1 traffic light, 2 handbags, 1 suitcase, 1 sports ball, 1 baseball glove, 20 tvs, 2 cell phones, 2 clocks, 1869.5ms
# Speed: 2.0ms preprocess, 1869.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 3 cars, 1 traffic light, 1 handbag, 1 suitcase, 1 sports ball, 1 baseball glove, 15 tvs, 2 cell phones, 2 clocks, 1844.9ms
# Speed: 2.0ms preprocess, 1844.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 cars, 1 train, 1 traffic light, 1 suitcase, 1 sports ball, 15 tvs, 1 cell phone, 1 clock, 1848.7ms
# Speed: 2.0ms preprocess, 1848.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 cars, 1 traffic light, 1 suitcase, 1 sports ball, 1 skateboard, 16 tvs, 1 cell phone, 1 clock, 1876.1ms
# Speed: 2.0ms preprocess, 1876.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 airplane, 1 traffic light, 3 suitcases, 1 sports ball, 13 tvs, 1 cell phone, 1860.6ms
# Speed: 2.0ms preprocess, 1860.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 cars, 1 traffic light, 1 sports ball, 3 skateboards, 15 tvs, 1 cell phone, 1 clock, 1864.9ms
# Speed: 3.0ms preprocess, 1864.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 cars, 2 trains, 2 traffic lights, 5 suitcases, 1 sports ball, 1 surfboard, 15 tvs, 1 mouse, 1 cell phone, 2 clocks, 1840.6ms
# Speed: 2.0ms preprocess, 1840.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 train, 1 traffic light, 5 suitcases, 1 sports ball, 16 tvs, 1 cell phone, 1 clock, 1852.9ms
# Speed: 2.0ms preprocess, 1852.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 train, 1 traffic light, 6 suitcases, 1 sports ball, 15 tvs, 1 laptop, 1 cell phone, 1868.2ms
# Speed: 1.0ms preprocess, 1868.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 train, 1 traffic light, 4 suitcases, 1 sports ball, 1 skateboard, 13 tvs, 1 cell phone, 2 clocks, 1846.2ms
# Speed: 1.0ms preprocess, 1846.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 traffic light, 5 suitcases, 1 sports ball, 14 tvs, 1 cell phone, 1 clock, 1851.2ms
# Speed: 1.0ms preprocess, 1851.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 traffic light, 5 suitcases, 1 sports ball, 2 bottles, 1 cup, 1 bowl, 15 tvs, 1 cell phone, 1 clock, 1845.8ms
# Speed: 2.0ms preprocess, 1845.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 5 suitcases, 1 sports ball, 1 baseball bat, 1 baseball glove, 1 skateboard, 17 tvs, 2 cell phones, 2 clocks, 1841.0ms
# Speed: 2.0ms preprocess, 1841.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 bicycle, 2 suitcases, 1 sports ball, 1 baseball bat, 1 baseball glove, 2 skateboards, 1 chair, 14 tvs, 1 cell phone, 2 clocks, 1832.0ms
# Speed: 1.0ms preprocess, 1832.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 handbag, 4 suitcases, 1 sports ball, 1 baseball bat, 2 bottles, 16 tvs, 3 cell phones, 1 clock, 1855.6ms
# Speed: 2.0ms preprocess, 1855.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 traffic light, 1 bench, 1 handbag, 3 suitcases, 1 sports ball, 1 skateboard, 15 tvs, 1 cell phone, 2 clocks, 1864.4ms
# Speed: 2.0ms preprocess, 1864.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 traffic light, 1 bench, 2 handbags, 6 suitcases, 1 sports ball, 12 tvs, 2 remotes, 2 cell phones, 2 clocks, 1858.7ms
# Speed: 2.0ms preprocess, 1858.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 traffic light, 1 handbag, 2 suitcases, 1 sports ball, 11 tvs, 2 cell phones, 3 clocks, 1883.2ms
# Speed: 2.0ms preprocess, 1883.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 train, 1 traffic light, 2 handbags, 1 suitcase, 1 sports ball, 11 tvs, 1 cell phone, 1 clock, 1883.1ms
# Speed: 2.0ms preprocess, 1883.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 cars, 1 train, 1 traffic light, 1 handbag, 1 suitcase, 1 sports ball, 1 skateboard, 14 tvs, 1 cell phone, 3 clocks, 1878.6ms
# Speed: 2.0ms preprocess, 1878.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 cars, 1 train, 1 traffic light, 1 bench, 1 suitcase, 1 sports ball, 1 skateboard, 13 tvs, 1 cell phone, 1 clock, 1844.0ms
# Speed: 1.6ms preprocess, 1844.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 cars, 3 trains, 1 traffic light, 1 bench, 2 handbags, 4 suitcases, 4 skateboards, 13 tvs, 1 cell phone, 3 clocks, 1849.6ms
# Speed: 3.0ms preprocess, 1849.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 2 trains, 1 traffic light, 1 handbag, 1 suitcase, 5 skateboards, 10 tvs, 3 cell phones, 1 clock, 1836.9ms
# Speed: 2.0ms preprocess, 1836.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 2 trains, 1 traffic light, 1 handbag, 1 suitcase, 2 skateboards, 14 tvs, 1 mouse, 1 cell phone, 3 clocks, 1831.8ms
# Speed: 2.0ms preprocess, 1831.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 2 trains, 1 traffic light, 1 handbag, 3 suitcases, 15 tvs, 2 cell phones, 1847.4ms
# Speed: 2.0ms preprocess, 1847.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 train, 1 traffic light, 1 handbag, 2 suitcases, 1 sports ball, 11 tvs, 2 cell phones, 2 clocks, 1892.3ms
# Speed: 2.0ms preprocess, 1892.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 cars, 3 trains, 1 traffic light, 1 cat, 1 suitcase, 1 sports ball, 1 baseball bat, 1 baseball glove, 12 tvs, 2 cell phones, 1 clock, 1871.2ms
# Speed: 2.0ms preprocess, 1871.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 train, 1 traffic light, 1 sports ball, 13 tvs, 2 cell phones, 1 clock, 1923.4ms
# Speed: 2.0ms preprocess, 1923.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 train, 1 traffic light, 1 backpack, 1 sports ball, 18 tvs, 2 cell phones, 1 clock, 1836.2ms
# Speed: 1.0ms preprocess, 1836.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 2 trains, 1 traffic light, 1 backpack, 1 suitcase, 1 sports ball, 15 tvs, 2 cell phones, 1 clock, 1907.3ms
# Speed: 2.0ms preprocess, 1907.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 cars, 2 trains, 1 traffic light, 1 sports ball, 12 tvs, 1 laptop, 3 cell phones, 1 clock, 1850.7ms
# Speed: 1.0ms preprocess, 1850.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 cars, 1 train, 1 traffic light, 1 sports ball, 14 tvs, 1 laptop, 3 cell phones, 2 clocks, 1847.5ms
# Speed: 1.0ms preprocess, 1847.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 4 trains, 1 traffic light, 1 backpack, 1 suitcase, 1 sports ball, 2 bottles, 10 tvs, 1 laptop, 3 cell phones, 1 clock, 1852.4ms
# Speed: 2.0ms preprocess, 1852.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 car, 1 train, 1 traffic light, 1 backpack, 2 suitcases, 1 sports ball, 12 tvs, 3 cell phones, 2 clocks, 1836.1ms
# Speed: 1.0ms preprocess, 1836.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 3 cars, 2 trains, 1 traffic light, 1 sports ball, 9 tvs, 1 laptop, 3 cell phones, 2 clocks, 1839.3ms
# Speed: 1.0ms preprocess, 1839.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 cars, 2 trains, 1 traffic light, 1 backpack, 3 suitcases, 1 sports ball, 8 tvs, 3 cell phones, 1 clock, 1835.8ms
# Speed: 2.0ms preprocess, 1835.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 train, 1 traffic light, 1 backpack, 2 suitcases, 1 skis, 1 sports ball, 12 tvs, 1 laptop, 4 cell phones, 1 clock, 1835.9ms
# Speed: 2.0ms preprocess, 1835.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 4 trains, 1 traffic light, 1 handbag, 2 suitcases, 1 sports ball, 7 tvs, 4 cell phones, 1843.0ms
# Speed: 3.0ms preprocess, 1843.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 trains, 1 traffic light, 1 stop sign, 1 backpack, 1 handbag, 2 suitcases, 1 sports ball, 8 tvs, 4 cell phones, 1 clock, 1835.6ms
# Speed: 1.0ms preprocess, 1835.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 trains, 1 traffic light, 1 backpack, 1 suitcase, 1 sports ball, 1 bottle, 10 tvs, 4 cell phones, 1 clock, 1847.6ms
# Speed: 2.0ms preprocess, 1847.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 2 trains, 1 traffic light, 1 suitcase, 1 sports ball, 4 bottles, 10 tvs, 4 cell phones, 1 clock, 1842.3ms
# Speed: 1.0ms preprocess, 1842.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 traffic light, 2 backpacks, 1 suitcase, 1 sports ball, 8 bottles, 9 tvs, 4 cell phones, 1 clock, 1837.8ms
# Speed: 1.0ms preprocess, 1837.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 traffic light, 1 suitcase, 1 sports ball, 1 bottle, 8 tvs, 1 laptop, 4 cell phones, 1 clock, 1844.4ms
# Speed: 2.0ms preprocess, 1844.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 2 trains, 1 traffic light, 2 backpacks, 3 suitcases, 1 sports ball, 1 bottle, 9 tvs, 1 laptop, 5 cell phones, 1 clock, 1834.2ms
# Speed: 2.0ms preprocess, 1834.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 trains, 1 traffic light, 2 backpacks, 4 suitcases, 1 sports ball, 2 bottles, 10 tvs, 2 cell phones, 1 clock, 1829.6ms
# Speed: 2.0ms preprocess, 1829.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 cars, 3 trains, 1 traffic light, 2 backpacks, 2 suitcases, 1 skis, 1 sports ball, 2 bottles, 9 tvs, 2 cell phones, 1836.5ms
# Speed: 1.0ms preprocess, 1836.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 motorcycle, 1 train, 1 traffic light, 1 stop sign, 4 suitcases, 1 sports ball, 2 bottles, 1 chair, 10 tvs, 2 cell phones, 2 books, 1831.7ms
# Speed: 2.0ms preprocess, 1831.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 cars, 1 motorcycle, 1 train, 1 traffic light, 1 stop sign, 2 backpacks, 3 suitcases, 1 sports ball, 1 bottle, 10 tvs, 3 cell phones, 1 clock, 1908.2ms
# Speed: 2.0ms preprocess, 1908.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 traffic light, 1 stop sign, 2 backpacks, 1 sports ball, 1 bottle, 9 tvs, 1 laptop, 3 cell phones, 1 clock, 2097.2ms
# Speed: 1.0ms preprocess, 2097.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 traffic light, 1 stop sign, 1 backpack, 1 suitcase, 1 sports ball, 1 bottle, 10 tvs, 2 laptops, 2 cell phones, 1 clock, 1909.9ms
# Speed: 2.0ms preprocess, 1909.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 2 traffic lights, 1 stop sign, 1 backpack, 1 suitcase, 1 sports ball, 1 bottle, 1 chair, 10 tvs, 3 cell phones, 1 clock, 1864.7ms
# Speed: 1.9ms preprocess, 1864.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 train, 2 traffic lights, 1 stop sign, 1 backpack, 1 suitcase, 1 sports ball, 1 bottle, 1 chair, 11 tvs, 3 cell phones, 1 clock, 1862.8ms
# Speed: 2.0ms preprocess, 1862.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 2 traffic lights, 2 suitcases, 1 sports ball, 1 bottle, 1 chair, 11 tvs, 3 cell phones, 4 clocks, 2028.1ms
# Speed: 2.0ms preprocess, 2028.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 2 traffic lights, 1 suitcase, 1 sports ball, 1 bottle, 1 chair, 8 tvs, 1 cell phone, 2 clocks, 2045.5ms
# Speed: 3.0ms preprocess, 2045.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 traffic lights, 1 suitcase, 1 sports ball, 1 chair, 8 tvs, 2 cell phones, 4 clocks, 1870.1ms
# Speed: 2.0ms preprocess, 1870.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 2 traffic lights, 1 sports ball, 1 chair, 9 tvs, 1 laptop, 2 cell phones, 2 books, 1 clock, 1853.9ms
# Speed: 2.0ms preprocess, 1853.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 traffic light, 2 sports balls, 1 chair, 8 tvs, 1 laptop, 3 cell phones, 3 clocks, 1857.9ms
# Speed: 1.0ms preprocess, 1857.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 train, 2 traffic lights, 2 sports balls, 1 chair, 11 tvs, 1 cell phone, 3 clocks, 1865.2ms
# Speed: 2.0ms preprocess, 1865.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 train, 1 traffic light, 1 sports ball, 1 chair, 8 tvs, 2 cell phones, 2 clocks, 1855.7ms
# Speed: 1.0ms preprocess, 1855.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 1 traffic light, 1 sports ball, 1 chair, 10 tvs, 2 cell phones, 2 clocks, 1858.9ms
# Speed: 2.0ms preprocess, 1858.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 train, 2 traffic lights, 1 chair, 11 tvs, 2 cell phones, 2 clocks, 1862.4ms
# Speed: 2.0ms preprocess, 1862.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 train, 2 traffic lights, 1 chair, 14 tvs, 1 cell phone, 1 clock, 1850.3ms
# Speed: 1.0ms preprocess, 1850.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 train, 2 traffic lights, 1 stop sign, 12 tvs, 2 cell phones, 1 clock, 1855.6ms
# Speed: 2.0ms preprocess, 1855.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 train, 2 traffic lights, 10 tvs, 2 cell phones, 2 clocks, 1865.5ms
# Speed: 1.0ms preprocess, 1865.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 2 traffic lights, 1 chair, 11 tvs, 1 laptop, 2 cell phones, 2 clocks, 1868.9ms
# Speed: 2.0ms preprocess, 1868.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 2 traffic lights, 1 stop sign, 10 tvs, 1 cell phone, 2 clocks, 1819.9ms
# Speed: 2.0ms preprocess, 1819.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 3 traffic lights, 1 stop sign, 13 tvs, 1 laptop, 1 cell phone, 2 clocks, 1871.9ms
# Speed: 2.0ms preprocess, 1871.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 train, 2 traffic lights, 1 stop sign, 9 tvs, 1 cell phone, 3 clocks, 1846.4ms
# Speed: 2.0ms preprocess, 1846.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 train, 3 traffic lights, 1 stop sign, 1 suitcase, 1 sports ball, 9 tvs, 1 cell phone, 2 clocks, 1848.9ms
# Speed: 2.0ms preprocess, 1848.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 bus, 2 trains, 3 traffic lights, 1 stop sign, 1 sports ball, 9 tvs, 1 cell phone, 1 clock, 1856.2ms
# Speed: 3.0ms preprocess, 1856.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 2 traffic lights, 1 stop sign, 1 suitcase, 1 sports ball, 10 tvs, 1 cell phone, 1 clock, 1846.1ms
# Speed: 2.0ms preprocess, 1846.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 buss, 1 train, 1 traffic light, 1 stop sign, 1 sports ball, 12 tvs, 1 cell phone, 2 clocks, 1859.7ms
# Speed: 2.0ms preprocess, 1859.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 bus, 1 train, 3 traffic lights, 1 stop sign, 1 sports ball, 12 tvs, 1 cell phone, 2 clocks, 1842.5ms
# Speed: 2.0ms preprocess, 1842.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 train, 1 traffic light, 1 stop sign, 1 sports ball, 11 tvs, 1 cell phone, 1 clock, 1849.7ms
# Speed: 2.7ms preprocess, 1849.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 3 trains, 1 traffic light, 1 stop sign, 1 bench, 1 suitcase, 1 sports ball, 6 tvs, 1 laptop, 1 cell phone, 3 clocks, 1833.2ms
# Speed: 2.0ms preprocess, 1833.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 train, 2 traffic lights, 1 stop sign, 1 sports ball, 6 tvs, 1 keyboard, 1 cell phone, 1 clock, 1840.5ms
# Speed: 2.0ms preprocess, 1840.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 train, 1 traffic light, 1 stop sign, 1 sports ball, 1 bottle, 6 tvs, 1 laptop, 1 cell phone, 2 clocks, 1821.5ms
# Speed: 1.0ms preprocess, 1821.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 traffic light, 1 stop sign, 1 sports ball, 6 tvs, 1 laptop, 1 cell phone, 2 clocks, 1831.9ms
# Speed: 2.0ms preprocess, 1831.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 stop sign, 1 sports ball, 7 tvs, 1 laptop, 3 cell phones, 2 clocks, 1840.4ms
# Speed: 1.7ms preprocess, 1840.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 stop sign, 1 sports ball, 8 tvs, 1 laptop, 1 cell phone, 1 book, 3 clocks, 1835.8ms
# Speed: 2.0ms preprocess, 1835.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 stop sign, 1 sports ball, 9 tvs, 1 laptop, 2 cell phones, 1 book, 2 clocks, 1864.4ms
# Speed: 2.0ms preprocess, 1864.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 car, 1 train, 2 traffic lights, 1 stop sign, 1 sports ball, 3 bottles, 9 tvs, 1 laptop, 2 cell phones, 1 book, 3 clocks, 1853.5ms
# Speed: 2.0ms preprocess, 1853.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 train, 2 traffic lights, 1 stop sign, 1 sports ball, 2 bottles, 6 tvs, 1 laptop, 2 cell phones, 2 books, 2 clocks, 1887.4ms
# Speed: 2.0ms preprocess, 1887.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 train, 3 traffic lights, 1 stop sign, 1 suitcase, 5 tvs, 2 cell phones, 2 books, 2 clocks, 1863.4ms
# Speed: 3.0ms preprocess, 1863.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 train, 1 traffic light, 1 stop sign, 1 tie, 6 tvs, 2 cell phones, 1 book, 2 clocks, 1856.1ms
# Speed: 2.0ms preprocess, 1856.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 trains, 1 traffic light, 1 stop sign, 4 bottles, 4 tvs, 2 cell phones, 2 books, 2 clocks, 1855.1ms
# Speed: 2.0ms preprocess, 1855.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 car, 4 trains, 3 traffic lights, 1 stop sign, 1 tie, 3 bottles, 3 tvs, 2 cell phones, 2 books, 3 clocks, 1832.6ms
# Speed: 3.0ms preprocess, 1832.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 3 trains, 1 traffic light, 1 stop sign, 1 umbrella, 1 tie, 4 bottles, 4 tvs, 1 cell phone, 1 book, 1 clock, 1832.9ms
# Speed: 1.0ms preprocess, 1832.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 cars, 2 trains, 1 traffic light, 1 stop sign, 1 umbrella, 1 bottle, 4 tvs, 1 cell phone, 3 books, 2 clocks, 1820.9ms
# Speed: 2.0ms preprocess, 1820.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 trains, 2 traffic lights, 1 stop sign, 1 bench, 2 umbrellas, 1 tie, 4 tvs, 1 cell phone, 3 books, 4 clocks, 1833.3ms
# Speed: 2.0ms preprocess, 1833.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 trains, 2 traffic lights, 1 stop sign, 2 umbrellas, 1 tie, 2 bottles, 4 tvs, 2 cell phones, 3 books, 3 clocks, 1824.9ms
# Speed: 2.0ms preprocess, 1824.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 trains, 1 stop sign, 1 bench, 1 umbrella, 1 tie, 4 bottles, 1 chair, 5 tvs, 2 cell phones, 4 books, 5 clocks, 1867.6ms
# Speed: 2.0ms preprocess, 1867.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 trains, 1 stop sign, 1 bench, 1 umbrella, 1 tie, 4 bottles, 1 chair, 5 tvs, 1 cell phone, 5 books, 6 clocks, 1830.7ms
# Speed: 2.0ms preprocess, 1830.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 2 trains, 1 stop sign, 1 umbrella, 1 tie, 8 bottles, 1 chair, 5 tvs, 1 cell phone, 6 books, 6 clocks, 1829.2ms
# Speed: 2.2ms preprocess, 1829.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 cars, 2 trains, 1 stop sign, 1 bench, 1 tie, 1 sports ball, 12 bottles, 1 chair, 1 bed, 5 tvs, 1 cell phone, 6 books, 5 clocks, 1909.4ms
# Speed: 2.0ms preprocess, 1909.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 2 trains, 1 traffic light, 1 stop sign, 2 benchs, 1 tie, 1 sports ball, 9 bottles, 2 chairs, 1 bed, 4 tvs, 2 cell phones, 4 books, 7 clocks, 1 vase, 1872.7ms
# Speed: 2.0ms preprocess, 1872.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 2 trains, 1 stop sign, 1 bench, 1 tie, 1 suitcase, 11 bottles, 1 chair, 1 bed, 5 tvs, 2 cell phones, 4 books, 8 clocks, 1 vase, 1893.4ms
# Speed: 2.0ms preprocess, 1893.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 trains, 1 stop sign, 1 bench, 1 tie, 1 suitcase, 16 bottles, 1 chair, 1 bed, 4 tvs, 2 cell phones, 6 books, 7 clocks, 1855.7ms
# Speed: 2.0ms preprocess, 1855.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 trains, 1 stop sign, 2 benchs, 1 tie, 1 sports ball, 9 bottles, 1 chair, 1 bed, 4 tvs, 2 cell phones, 4 books, 7 clocks, 1833.9ms
# Speed: 2.0ms preprocess, 1833.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 trains, 1 stop sign, 2 benchs, 1 tie, 1 sports ball, 7 bottles, 1 chair, 1 bed, 3 tvs, 1 cell phone, 4 books, 5 clocks, 3 vases, 1856.8ms
# Speed: 2.0ms preprocess, 1856.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 3 trains, 1 stop sign, 1 tie, 1 sports ball, 13 bottles, 1 chair, 5 tvs, 2 cell phones, 1 refrigerator, 4 books, 5 clocks, 3 vases, 1855.7ms
# Speed: 2.0ms preprocess, 1855.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 trains, 1 boat, 1 stop sign, 1 tie, 1 suitcase, 12 bottles, 1 chair, 4 tvs, 2 cell phones, 5 books, 4 clocks, 1855.1ms
# Speed: 2.0ms preprocess, 1855.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 trains, 1 stop sign, 1 tie, 1 suitcase, 1 sports ball, 7 bottles, 1 chair, 7 tvs, 1 cell phone, 5 books, 4 clocks, 5 vases, 1830.5ms
# Speed: 2.0ms preprocess, 1830.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 trains, 1 stop sign, 1 bench, 1 tie, 15 bottles, 1 chair, 7 tvs, 1 cell phone, 4 books, 5 clocks, 2 vases, 1862.0ms
# Speed: 3.0ms preprocess, 1862.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 trains, 1 stop sign, 2 benchs, 15 bottles, 1 chair, 5 tvs, 2 cell phones, 6 books, 4 clocks, 3 vases, 1845.9ms
# Speed: 2.0ms preprocess, 1845.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 trains, 1 stop sign, 2 benchs, 15 bottles, 3 wine glasss, 1 chair, 1 dining table, 8 tvs, 2 cell phones, 1 refrigerator, 5 books, 5 clocks, 1 vase, 1845.0ms
# Speed: 1.0ms preprocess, 1845.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 trains, 1 stop sign, 1 bench, 1 tie, 16 bottles, 2 wine glasss, 1 chair, 4 tvs, 3 cell phones, 4 books, 4 clocks, 1843.8ms
# Speed: 2.0ms preprocess, 1843.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 trains, 1 boat, 1 stop sign, 1 tie, 15 bottles, 2 wine glasss, 1 bowl, 1 chair, 1 dining table, 6 tvs, 2 cell phones, 1 refrigerator, 4 books, 5 clocks, 1 vase, 1839.7ms
# Speed: 2.0ms preprocess, 1839.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 trains, 2 boats, 1 stop sign, 2 benchs, 1 handbag, 15 bottles, 5 wine glasss, 1 chair, 1 couch, 1 dining table, 5 tvs, 1 cell phone, 5 books, 7 clocks, 9 vases, 1854.8ms
# Speed: 2.0ms preprocess, 1854.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 train, 1 stop sign, 1 bench, 1 handbag, 18 bottles, 2 wine glasss, 1 chair, 1 couch, 8 tvs, 1 cell phone, 1 refrigerator, 3 books, 6 clocks, 5 vases, 1862.6ms
# Speed: 2.0ms preprocess, 1862.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 1 boat, 1 stop sign, 1 bench, 16 bottles, 2 wine glasss, 1 chair, 10 tvs, 2 cell phones, 4 books, 6 clocks, 8 vases, 1869.6ms
# Speed: 2.0ms preprocess, 1869.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 train, 1 boat, 2 stop signs, 1 bench, 1 tie, 15 bottles, 5 wine glasss, 1 cup, 1 chair, 9 tvs, 1 cell phone, 6 books, 7 clocks, 20 vases, 1857.3ms
# Speed: 1.0ms preprocess, 1857.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 car, 2 stop signs, 23 bottles, 4 wine glasss, 8 tvs, 1 cell phone, 1 refrigerator, 6 books, 6 clocks, 8 vases, 1846.5ms
# Speed: 2.0ms preprocess, 1846.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 car, 1 train, 2 stop signs, 1 bench, 17 bottles, 5 wine glasss, 6 tvs, 1 cell phone, 6 books, 7 clocks, 9 vases, 1855.8ms
# Speed: 2.0ms preprocess, 1855.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 train, 2 stop signs, 1 bench, 1 skis, 1 surfboard, 11 bottles, 2 wine glasss, 7 tvs, 1 cell phone, 7 books, 7 clocks, 12 vases, 1895.3ms
# Speed: 2.0ms preprocess, 1895.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 train, 1 stop sign, 22 bottles, 2 wine glasss, 9 tvs, 1 refrigerator, 6 books, 6 clocks, 10 vases, 1 toothbrush, 1904.8ms
# Speed: 2.0ms preprocess, 1904.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 1 stop sign, 21 bottles, 6 wine glasss, 6 tvs, 1 cell phone, 1 refrigerator, 6 books, 5 clocks, 12 vases, 1859.0ms
# Speed: 2.0ms preprocess, 1859.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 train, 2 stop signs, 21 bottles, 4 wine glasss, 1 fork, 6 tvs, 7 books, 5 clocks, 16 vases, 1860.1ms
# Speed: 2.0ms preprocess, 1860.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 2 stop signs, 1 bench, 11 bottles, 5 wine glasss, 8 tvs, 1 refrigerator, 6 books, 4 clocks, 16 vases, 1851.0ms
# Speed: 2.0ms preprocess, 1851.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 train, 2 stop signs, 13 bottles, 2 wine glasss, 6 tvs, 1 cell phone, 6 books, 4 clocks, 15 vases, 1827.2ms
# Speed: 2.0ms preprocess, 1827.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 2 stop signs, 22 bottles, 4 wine glasss, 7 tvs, 1 cell phone, 6 books, 5 clocks, 13 vases, 1825.6ms
# Speed: 2.0ms preprocess, 1825.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 2 stop signs, 2 benchs, 1 sports ball, 23 bottles, 3 wine glasss, 8 tvs, 1 cell phone, 4 books, 3 clocks, 15 vases, 1861.7ms
# Speed: 1.0ms preprocess, 1861.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 2 stop signs, 2 benchs, 1 suitcase, 1 sports ball, 26 bottles, 2 wine glasss, 1 couch, 9 tvs, 1 cell phone, 5 books, 5 clocks, 17 vases, 1873.1ms
# Speed: 2.0ms preprocess, 1873.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 2 stop signs, 1 bench, 22 bottles, 3 wine glasss, 1 couch, 11 tvs, 1 cell phone, 4 books, 3 clocks, 18 vases, 1848.0ms
# Speed: 3.0ms preprocess, 1848.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 2 stop signs, 1 sports ball, 24 bottles, 2 wine glasss, 1 chair, 9 tvs, 1 cell phone, 4 books, 5 clocks, 9 vases, 1831.5ms
# Speed: 2.2ms preprocess, 1831.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 2 stop signs, 28 bottles, 4 wine glasss, 13 tvs, 1 cell phone, 1 refrigerator, 4 books, 5 clocks, 2 vases, 1843.1ms
# Speed: 2.0ms preprocess, 1843.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 2 stop signs, 22 bottles, 3 wine glasss, 1 chair, 1 dining table, 12 tvs, 1 cell phone, 4 books, 3 clocks, 18 vases, 1871.6ms
# Speed: 1.0ms preprocess, 1871.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 2 stop signs, 25 bottles, 3 wine glasss, 1 chair, 1 dining table, 11 tvs, 1 cell phone, 4 books, 4 clocks, 7 vases, 1874.7ms
# Speed: 1.0ms preprocess, 1874.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 2 stop signs, 25 bottles, 3 wine glasss, 10 tvs, 2 cell phones, 5 books, 5 clocks, 17 vases, 1850.9ms
# Speed: 2.0ms preprocess, 1850.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 2 stop signs, 1 suitcase, 24 bottles, 10 tvs, 2 cell phones, 4 books, 4 clocks, 14 vases, 1842.0ms
# Speed: 2.0ms preprocess, 1842.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 2 stop signs, 29 bottles, 2 wine glasss, 13 tvs, 2 cell phones, 4 books, 4 clocks, 6 vases, 1835.4ms
# Speed: 1.0ms preprocess, 1835.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 train, 2 stop signs, 1 bench, 25 bottles, 2 wine glasss, 11 tvs, 2 cell phones, 4 books, 4 clocks, 9 vases, 1847.3ms
# Speed: 2.0ms preprocess, 1847.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 train, 2 stop signs, 1 bench, 27 bottles, 1 wine glass, 8 tvs, 2 cell phones, 4 books, 4 clocks, 15 vases, 1856.4ms
# Speed: 2.0ms preprocess, 1856.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 2 stop signs, 2 benchs, 26 bottles, 2 wine glasss, 2 dining tables, 10 tvs, 2 cell phones, 4 books, 3 clocks, 16 vases, 1845.9ms
# Speed: 2.0ms preprocess, 1845.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bus, 1 train, 2 stop signs, 1 bench, 18 bottles, 3 cups, 1 chair, 1 dining table, 10 tvs, 3 cell phones, 4 books, 3 clocks, 18 vases, 1823.4ms
# Speed: 2.0ms preprocess, 1823.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bus, 1 train, 2 stop signs, 1 bench, 14 bottles, 1 cup, 1 chair, 1 dining table, 6 tvs, 3 cell phones, 4 books, 3 clocks, 24 vases, 1831.5ms
# Speed: 2.0ms preprocess, 1831.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 train, 2 stop signs, 1 bench, 18 bottles, 2 wine glasss, 1 chair, 6 tvs, 2 cell phones, 4 books, 3 clocks, 18 vases, 1848.5ms
# Speed: 3.0ms preprocess, 1848.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 2 stop signs, 22 bottles, 1 wine glass, 1 chair, 6 tvs, 2 cell phones, 4 books, 3 clocks, 19 vases, 1841.8ms
# Speed: 2.0ms preprocess, 1841.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 2 stop signs, 25 bottles, 1 wine glass, 1 dining table, 7 tvs, 1 cell phone, 6 books, 3 clocks, 20 vases, 1837.5ms
# Speed: 2.0ms preprocess, 1837.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 2 stop signs, 29 bottles, 1 chair, 1 dining table, 8 tvs, 2 cell phones, 5 books, 3 clocks, 15 vases, 1828.7ms
# Speed: 2.0ms preprocess, 1828.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 2 stop signs, 28 bottles, 1 dining table, 7 tvs, 1 cell phone, 3 books, 3 clocks, 14 vases, 1833.8ms
# Speed: 1.0ms preprocess, 1833.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 2 stop signs, 30 bottles, 2 wine glasss, 4 tvs, 1 cell phone, 4 books, 3 clocks, 12 vases, 1837.8ms
# Speed: 2.0ms preprocess, 1837.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 1 stop sign, 33 bottles, 1 wine glass, 4 tvs, 1 cell phone, 4 books, 3 clocks, 2 vases, 1841.8ms
# Speed: 2.0ms preprocess, 1841.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 1 stop sign, 39 bottles, 1 wine glass, 1 cup, 3 tvs, 1 cell phone, 2 books, 3 clocks, 3 vases, 1836.0ms
# Speed: 2.0ms preprocess, 1836.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 train, 1 stop sign, 38 bottles, 1 wine glass, 4 tvs, 1 cell phone, 3 books, 3 clocks, 3 vases, 1846.2ms
# Speed: 2.0ms preprocess, 1846.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 train, 1 traffic light, 1 stop sign, 35 bottles, 1 wine glass, 4 tvs, 1 cell phone, 2 clocks, 2 vases, 1915.5ms
# Speed: 2.0ms preprocess, 1915.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 train, 2 stop signs, 33 bottles, 1 wine glass, 1 spoon, 4 tvs, 1 cell phone, 3 clocks, 1896.5ms
# Speed: 2.0ms preprocess, 1896.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 traffic light, 2 stop signs, 15 bottles, 5 wine glasss, 8 tvs, 1 cell phone, 1 book, 2 clocks, 1915.2ms
# Speed: 2.0ms preprocess, 1915.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 train, 1 traffic light, 1 stop sign, 1 tennis racket, 15 bottles, 2 wine glasss, 6 tvs, 1 cell phone, 1 book, 2 clocks, 1888.8ms
# Speed: 2.0ms preprocess, 1888.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 train, 1 traffic light, 2 stop signs, 19 bottles, 2 wine glasss, 6 tvs, 1 cell phone, 2 clocks, 1891.7ms
# Speed: 2.0ms preprocess, 1891.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 1 traffic light, 2 stop signs, 1 tennis racket, 17 bottles, 1 wine glass, 8 tvs, 1 cell phone, 3 clocks, 1849.4ms
# Speed: 1.8ms preprocess, 1849.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 train, 1 traffic light, 2 stop signs, 12 bottles, 3 wine glasss, 7 tvs, 1 cell phone, 2 clocks, 1851.9ms
# Speed: 2.0ms preprocess, 1851.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 train, 1 traffic light, 2 stop signs, 1 tennis racket, 13 bottles, 3 wine glasss, 1 cup, 4 tvs, 1 remote, 1 cell phone, 1 book, 1 clock, 1853.4ms
# Speed: 3.0ms preprocess, 1853.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 1 traffic light, 2 stop signs, 1 tennis racket, 14 bottles, 3 wine glasss, 1 cup, 4 tvs, 1 cell phone, 1 book, 1 clock, 1820.7ms
# Speed: 1.0ms preprocess, 1820.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 train, 1 traffic light, 2 stop signs, 1 tennis racket, 13 bottles, 3 wine glasss, 5 tvs, 1 remote, 1 cell phone, 1 clock, 1835.7ms
# Speed: 2.0ms preprocess, 1835.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 train, 1 traffic light, 1 stop sign, 1 tennis racket, 24 bottles, 3 wine glasss, 1 cup, 4 tvs, 1 cell phone, 2 books, 3 clocks, 1 teddy bear, 1819.6ms
# Speed: 1.7ms preprocess, 1819.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 traffic light, 1 stop sign, 1 backpack, 1 tennis racket, 22 bottles, 1 wine glass, 4 tvs, 1 cell phone, 1 refrigerator, 3 clocks, 1 teddy bear, 1844.3ms
# Speed: 2.0ms preprocess, 1844.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 1 stop sign, 1 sports ball, 1 tennis racket, 12 bottles, 3 wine glasss, 1 cup, 2 spoons, 7 tvs, 1 cell phone, 3 clocks, 1850.5ms
# Speed: 2.0ms preprocess, 1850.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 1 stop sign, 1 sports ball, 1 tennis racket, 17 bottles, 1 wine glass, 1 dining table, 10 tvs, 1 cell phone, 3 clocks, 1869.1ms
# Speed: 1.0ms preprocess, 1869.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 traffic light, 1 stop sign, 1 sports ball, 16 bottles, 2 wine glasss, 1 dining table, 5 tvs, 1 cell phone, 3 clocks, 1900.7ms
# Speed: 2.0ms preprocess, 1900.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 traffic light, 1 stop sign, 14 bottles, 4 wine glasss, 1 dining table, 6 tvs, 1 cell phone, 3 clocks, 1893.6ms
# Speed: 2.0ms preprocess, 1893.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 1 stop sign, 12 bottles, 4 wine glasss, 1 dining table, 6 tvs, 1 cell phone, 2 clocks, 1 teddy bear, 1873.3ms
# Speed: 2.0ms preprocess, 1873.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 traffic light, 2 stop signs, 11 bottles, 3 wine glasss, 2 dining tables, 6 tvs, 1 cell phone, 1 book, 2 clocks, 1897.0ms
# Speed: 2.0ms preprocess, 1897.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 traffic light, 1 stop sign, 11 bottles, 3 wine glasss, 1 dining table, 6 tvs, 1 cell phone, 3 clocks, 4 vases, 1844.4ms
# Speed: 2.0ms preprocess, 1844.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 1 stop sign, 1 skis, 1 snowboard, 1 sports ball, 10 bottles, 3 wine glasss, 1 dining table, 5 tvs, 1 remote, 3 cell phones, 1 clock, 6 vases, 1864.1ms
# Speed: 1.0ms preprocess, 1864.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 traffic light, 1 stop sign, 10 bottles, 4 wine glasss, 1 dining table, 10 tvs, 1 remote, 2 cell phones, 2 clocks, 6 vases, 1833.0ms
# Speed: 1.0ms preprocess, 1833.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 traffic light, 1 stop sign, 1 sports ball, 8 bottles, 3 wine glasss, 1 dining table, 10 tvs, 2 cell phones, 1 book, 2 clocks, 5 vases, 1841.0ms
# Speed: 2.0ms preprocess, 1841.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 train, 1 traffic light, 1 stop sign, 14 bottles, 5 wine glasss, 2 dining tables, 5 tvs, 2 cell phones, 1 book, 2 clocks, 6 vases, 1890.0ms
# Speed: 1.0ms preprocess, 1890.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 train, 1 traffic light, 1 stop sign, 7 bottles, 4 wine glasss, 3 cups, 1 bowl, 1 dining table, 6 tvs, 2 cell phones, 1 book, 4 clocks, 8 vases, 1858.4ms
# Speed: 4.0ms preprocess, 1858.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 train, 1 traffic light, 1 stop sign, 5 bottles, 5 wine glasss, 3 cups, 1 dining table, 7 tvs, 1 remote, 2 cell phones, 1 book, 3 clocks, 9 vases, 1839.0ms
# Speed: 2.0ms preprocess, 1839.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 cars, 1 train, 1 traffic light, 1 stop sign, 7 bottles, 2 wine glasss, 2 cups, 1 knife, 1 bowl, 1 dining table, 6 tvs, 1 cell phone, 1 book, 3 clocks, 10 vases, 1822.1ms
# Speed: 2.0ms preprocess, 1822.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 cars, 1 train, 1 traffic light, 1 stop sign, 6 bottles, 2 wine glasss, 1 dining table, 8 tvs, 1 cell phone, 2 books, 2 clocks, 10 vases, 1843.7ms
# Speed: 2.0ms preprocess, 1843.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 train, 1 traffic light, 1 stop sign, 5 bottles, 1 wine glass, 1 cup, 1 dining table, 7 tvs, 1 cell phone, 1 book, 2 clocks, 10 vases, 1848.5ms
# Speed: 2.0ms preprocess, 1848.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 train, 1 traffic light, 1 stop sign, 1 sports ball, 3 bottles, 3 wine glasss, 1 cup, 1 dining table, 8 tvs, 4 remotes, 1 cell phone, 2 clocks, 7 vases, 1868.0ms
# Speed: 2.0ms preprocess, 1868.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 1 traffic light, 1 stop sign, 4 bottles, 2 wine glasss, 1 dining table, 7 tvs, 5 remotes, 1 cell phone, 2 clocks, 7 vases, 1848.4ms
# Speed: 1.0ms preprocess, 1848.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 train, 2 traffic lights, 2 stop signs, 4 bottles, 2 wine glasss, 1 cup, 1 dining table, 6 tvs, 5 remotes, 1 cell phone, 2 clocks, 6 vases, 1828.5ms
# Speed: 3.0ms preprocess, 1828.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 train, 2 traffic lights, 1 stop sign, 4 bottles, 2 wine glasss, 1 cup, 1 dining table, 6 tvs, 4 remotes, 1 cell phone, 2 clocks, 4 vases, 1853.3ms
# Speed: 2.0ms preprocess, 1853.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 traffic light, 1 stop sign, 1 tie, 1 sports ball, 3 bottles, 1 wine glass, 8 tvs, 2 remotes, 1 cell phone, 2 clocks, 4 vases, 1854.4ms
# Speed: 1.0ms preprocess, 1854.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 traffic light, 1 stop sign, 1 tie, 1 suitcase, 1 sports ball, 1 tennis racket, 4 bottles, 1 wine glass, 1 cup, 6 tvs, 2 remotes, 1 cell phone, 2 clocks, 4 vases, 1848.8ms
# Speed: 2.0ms preprocess, 1848.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 1 stop sign, 4 bottles, 1 wine glass, 5 tvs, 1 remote, 1 cell phone, 1 clock, 4 vases, 1870.2ms
# Speed: 2.0ms preprocess, 1870.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 traffic lights, 1 stop sign, 4 bottles, 1 wine glass, 5 tvs, 1 remote, 1 cell phone, 2 clocks, 4 vases, 1859.6ms
# Speed: 2.0ms preprocess, 1859.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 traffic lights, 1 stop sign, 1 umbrella, 4 bottles, 1 wine glass, 5 tvs, 7 remotes, 1 cell phone, 2 clocks, 4 vases, 1862.0ms
# Speed: 2.0ms preprocess, 1862.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 traffic lights, 1 stop sign, 1 umbrella, 3 bottles, 1 wine glass, 5 tvs, 1 cell phone, 2 clocks, 4 vases, 1849.2ms
# Speed: 2.0ms preprocess, 1849.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 car, 2 traffic lights, 1 stop sign, 1 umbrella, 4 bottles, 1 wine glass, 5 tvs, 1 cell phone, 2 clocks, 4 vases, 1840.4ms
# Speed: 2.0ms preprocess, 1840.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 traffic light, 1 stop sign, 1 umbrella, 4 bottles, 1 wine glass, 5 tvs, 1 remote, 1 cell phone, 2 clocks, 4 vases, 1832.5ms
# Speed: 2.0ms preprocess, 1832.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 traffic light, 1 stop sign, 1 umbrella, 4 bottles, 1 wine glass, 6 tvs, 3 remotes, 1 cell phone, 1 clock, 4 vases, 1819.8ms
# Speed: 4.0ms preprocess, 1819.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 traffic light, 1 stop sign, 1 umbrella, 4 bottles, 1 wine glass, 6 tvs, 2 remotes, 1 cell phone, 2 clocks, 4 vases, 1834.5ms
# Speed: 2.0ms preprocess, 1834.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 traffic light, 1 stop sign, 1 sports ball, 5 bottles, 1 wine glass, 5 tvs, 1 mouse, 2 remotes, 1 cell phone, 1 clock, 4 vases, 1828.1ms
# Speed: 2.0ms preprocess, 1828.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 1 traffic light, 1 stop sign, 4 bottles, 1 wine glass, 5 tvs, 1 mouse, 2 remotes, 1 cell phone, 2 clocks, 4 vases, 1845.4ms
# Speed: 3.0ms preprocess, 1845.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 train, 1 traffic light, 1 stop sign, 5 bottles, 1 wine glass, 9 tvs, 2 remotes, 1 cell phone, 1 clock, 4 vases, 1881.7ms
# Speed: 2.0ms preprocess, 1881.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 traffic light, 1 stop sign, 1 bench, 4 bottles, 2 wine glasss, 1 dining table, 6 tvs, 2 remotes, 1 cell phone, 2 clocks, 4 vases, 1907.7ms
# Speed: 1.0ms preprocess, 1907.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 traffic light, 1 stop sign, 1 bench, 4 bottles, 2 wine glasss, 7 tvs, 3 remotes, 1 cell phone, 2 clocks, 4 vases, 1890.3ms
# Speed: 1.6ms preprocess, 1890.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 cars, 1 traffic light, 1 stop sign, 4 bottles, 1 wine glass, 8 tvs, 1 remote, 1 cell phone, 2 clocks, 3 vases, 1921.4ms
# Speed: 2.0ms preprocess, 1921.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 1 train, 1 traffic light, 1 stop sign, 4 bottles, 1 wine glass, 1 chair, 8 tvs, 1 laptop, 2 remotes, 1 cell phone, 2 clocks, 3 vases, 1895.1ms
# Speed: 2.0ms preprocess, 1895.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 1 traffic light, 1 stop sign, 5 bottles, 1 wine glass, 1 chair, 11 tvs, 2 remotes, 1 cell phone, 2 clocks, 3 vases, 1862.6ms
# Speed: 1.0ms preprocess, 1862.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 1 traffic light, 5 bottles, 1 wine glass, 8 tvs, 2 laptops, 2 remotes, 1 cell phone, 1 book, 1 clock, 1 vase, 1853.5ms
# Speed: 2.0ms preprocess, 1853.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 cars, 1 traffic light, 5 bottles, 8 tvs, 2 laptops, 2 remotes, 1 cell phone, 1 clock, 1835.3ms
# Speed: 1.0ms preprocess, 1835.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 2 trains, 1 traffic light, 1 stop sign, 4 bottles, 6 tvs, 2 cell phones, 2 clocks, 1851.8ms
# Speed: 2.0ms preprocess, 1851.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 trains, 1 traffic light, 4 bottles, 6 tvs, 1 cell phone, 1 clock, 1837.3ms
# Speed: 2.0ms preprocess, 1837.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 trains, 1 traffic light, 4 bottles, 6 tvs, 1 cell phone, 2 clocks, 1846.9ms
# Speed: 2.0ms preprocess, 1846.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 trains, 1 traffic light, 4 bottles, 6 tvs, 1 cell phone, 2 clocks, 1856.0ms
# Speed: 2.0ms preprocess, 1856.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 1 traffic light, 5 bottles, 1 dining table, 6 tvs, 1 laptop, 1 cell phone, 1 oven, 2 clocks, 1841.8ms
# Speed: 3.0ms preprocess, 1841.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 trains, 2 traffic lights, 5 bottles, 5 tvs, 1 remote, 2 cell phones, 1 oven, 2 clocks, 1884.1ms
# Speed: 2.0ms preprocess, 1884.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1it [06:46, 406.67s/it]

# %%
def get_accuracy(pt, gt):
    total=0
    good=0
    for i in range(len(gt)):
        if intersection_over_union(gt[i], pt[i]) >= 0.3:
            good+=1
        total+=1
    return good/total

predicted = get_txt_files_from_folder("train/Task2/predited-truth")
ground = get_txt_files_from_folder("train/Task2/ground-truth")
pred_results = []
ground_results = []
acc_list=[]

for filepath in predicted:
    pred_results.append(extract_results(filepath))
for filepath in ground:
    ground_results.append(extract_results(filepath))

for pt,gt in zip(pred_results[:1], ground_results[:1]):
    acc = get_accuracy(pt, gt)
    acc_list.append(acc)

# %%
acc
# Out:
# 0.8520408163265306
